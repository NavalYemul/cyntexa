-- %%
Business case (Problem Statement)

cynatexa.

end case (bot) chat with the organisations data ( HR, sale, finance)


hr_dev
    bronze
    silver
    gold
sales_dev
    bronze
    silver 
    gold
finance_dev


data ingestion bronze

Data Ingestion 



gen ai 
Multi agent (langchian & langgraph, databricks sdk)
structured- genie -- all tables 
unstructured-  rag-- 

data prep-- embeding - vector seach-- 



model selection (open source, )




gen ai. 

chatDatabricks class talks to model, prompt ----- databricks apps 

rag-- chatdatabricks, ai search (vector)

agent-- chatdatabricsk, ai search, web serach, functions(tools ) , memeory, system prompt, etc etc  -- 

agentic ai-- 



model registry--- serving endpoint--- databricks apps
