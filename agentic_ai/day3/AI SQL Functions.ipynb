# %%
https://docs.databricks.com/aws/en/large-language-models/ai-functions

# %%
# %sql
SELECT ai_analyze_sentiment('I am sad')

# %%
# %sql
select * from samples.bakehouse.media_customer_reviews

# %%
# %sql
select *,ai_analyze_sentiment(review) as review_summary from samples.bakehouse.media_customer_reviews

# %%
# %sql
SELECT
ai_parse_document(
  content,
  map('version', '2.0')
) AS parsed
FROM READ_FILES('/Volumes/dev/bronze/raw/images/Screenshot 2026-08-15 at 14.17.30.png', format => 'binaryFile');
