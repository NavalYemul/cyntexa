# %%
Resume PDFs
   ↓
PDF extraction + chunking
   ↓
Delta Table
   ↓
Databricks AI Search index
   ↓
RAG Retriever Tool
   │
   ├── Resume Search Tool
   ├── Candidate Details Tool
   ├── Web Search Tool
   └── JD/Resume Match Tool
             ↓
        LangGraph Agent
             ↓
      MLflow ResponsesAgent
             ↓
      MLflow Model
             ↓
     Unity Catalog Registry
             ↓
      Model Serving Endpoint
             ↓
       Databricks App

# %%
resume_ai_agent/
│
├── 01_setup.py
├── 02_resume_rag.py
├── 03_tools.py
├── 04_langgraph_agent.py
├── 05_responses_agent.py
├── 06_test_agent.py
├── 07_log_model.py
├── 08_register_model.py
├── 09_deploy_endpoint.py
├── 10_test_endpoint.py
│
├── agent.py
├── tools.py
├── config.py
└── requirements.txt
