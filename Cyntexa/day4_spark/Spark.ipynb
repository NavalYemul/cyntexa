# %%
Pandas: single compute
Spark:  Distributed compute

# %%
print("hello")

# %%
spark

# %%
spark.version

# %%
RDD
DataFrame :  2D (rows and columns)
Dataset

# %%
employees = [{"name": "John D.", "age": 30},
  {"name": "Alice G.", "age": 25},
  {"name": "Bob T.", "age": 35},
  {"name": "Eve A.", "age": 28}]

# Create a DataFrame containing the employees data
df = spark.createDataFrame(employees)

# %%
df.display()

# %%
df.show()

# %% [markdown]
# Spark Reader API

# %% [markdown]
# Lazy evalution
#
#
# -- Transformation
# 1. spark.read
# 2. Filter
#
#
# --Action
#
# 1. display
# 2. show
# 3. write

# %%
Solapur to Pune to Jaipur sunday 

plan (1 mins)
4. flight


2. trian 
3.Car
1. Bus
5. bike
6. boat
7. walk / run 

action 
start executing the plan

# %%
df=spark.read.csv("/Volumes/dev/demo/raw/financial_dataset.csv")action

# %%
df=spark.read.csv("/Volumes/dev/demo/raw/financial_dataset.csv",header=True,inferSchema=True)

# %%
df.display()

# %%
df.filter("AccountType='Loan'")

# %%
df.filter("AccountType='Loan'").explain(True)

# %%
df.filter("AccountType='Loan'").display()

# %%
df.filter("AccountType='Loan'")

# %%
df.filter("AccountType='Loan'").display()

# %%
df=spark.read.csv("/Volumes/dev/demo/raw/financial_dataset.csv",header=True,inferSchema=True)

# %%
df.write.saveAsTable("dev.demo.financial")

# %%
df.write.mode("overwrite").saveAsTable("dev.demo.financial")

# %%
df=spark.read.csv("/Volumes/dev/demo/raw/financial_dataset.csv",header=True,inferSchema=True)
df.write.mode("overwrite").saveAsTable("dev.demo.financial")

# %%
( # reader API
spark
 .read
 .csv("/Volumes/dev/demo/raw/financial_dataset.csv",header=True,inferSchema=True)
 # Writer API
 .write
 .mode("overwrite")
 .saveAsTable("dev.demo.financial")
 )

# %%
# %sql
select * from dev.demo.financial

# %%
# %sql
desc extended dev.demo.financial
