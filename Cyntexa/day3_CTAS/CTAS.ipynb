-- %%
--read_file : csv,json,txt

-- %% [markdown]
-- CTAS: Create table as select

-- %%
drop table dev.demo.circuits_sql

-- %%
--CTAS
Create table dev.demo.circuits_sql as
select *,_metadata.file_name, _metadata.file_path, current_timestamp() as ingestion_ts from read_files("/Volumes/dev/demo/raw/circuits.csv")

-- %%
select * from dev.demo.circuits_sql

-- %%
create table dev.demo.drivers as 
select code, dob, driverId, driverRef,name.forename, name.surname, nationality, number, _metadata.file_name, _metadata.file_path, current_timestamp() as ingestion_ts from read_files("/Volumes/dev/demo/raw/drivers.json",format=>"json")

-- %% [markdown]
-- Iceberg table

-- %%
create table dev.demo.beta (id int, name string) using iceberg

-- %%
desc extended dev.demo.beta
