# %%
pandas: single core

spark: multiple core

# %%
import pandas

# %%
import pyspark.pandas as ps

# %%
df=spark.read.csv("path")

# %%
df=ps.read_csv("/Volumes/dev/bronze/raw/sales.csv")

# %%
df.display()

# %%
optimization 
1. spark: 
2. delta (optimze, z order , vacuum )
3. databricks: llm (compute: compute, vector index, endpoint, apps   )

# %%
df=spark.read.table("samples.bakehouse.sales_transactions")

# %%
df.filter("product='Outback Oatmeal'")

# %%
df.filter("product='Outback Oatmeal'").display()

# %%
Lazy Evalution

-- Transformation 

Narrow 
1. Read
2. filter


Wide (Shuffle )
1. groupby
2. join


-- Action

display
write

# %%
df.groupBy("product").count().display()

# %%
df2=spark.table("samples.bakehouse.sales_customers")

# %%
from pyspark.sql.functions import *

# %%
df_joined=df.join(broadcast(df2))

# %%
spark.version

# %%
df_joined.display()

# %%
df.display()

# %%
shuffle (join-- broadcast join)
skew -- (salt technique )
spill -- ( ) CACHE AND PERSIST
sereailsation

# %%
shuffle:

# %%
product_id, product_salt_id
1               1_1
1               1_2
1                1_3
1               1_4
2
3
3
1
3
4
2
2
3
4
