-- %%
select * from samples.bakehouse.sales_transactions where paymentMethod ='amex'

-- %%
Task: Explore the sample catalog. Do analysis on any schema

-- %%
select * from dev.demo.orderpriority_count
