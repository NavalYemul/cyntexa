# %%
# %run "/Workspace/Users/naval.datamaster@gmail.com/cyntexa/Cyntexa/day6_medallion_archtiecture/includes"

# %%
dbutils.widgets.text("catalog","default")
dbutils.widgets.text("table","default")

catalog=dbutils.widgets.get("catalog")
table=dbutils.widgets.get("table")

# %%
df=spark.read.csv(f"{input_path}{table}.csv",header=True,inferSchema=True)

df1=add_metadata_col(df)

df1.write.mode("overwrite").saveAsTable(f"{catalog}.bronze.{table}")
