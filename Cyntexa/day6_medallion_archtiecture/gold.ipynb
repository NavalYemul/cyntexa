-- %%
create or replace view identifier(:catalog ||'.gold.top_5_customers') as
(select customer_id, sum(total_amount) as total from identifier(:catalog ||'.silver.sales_cleaned') group by customer_id order by total desc limit 5)
