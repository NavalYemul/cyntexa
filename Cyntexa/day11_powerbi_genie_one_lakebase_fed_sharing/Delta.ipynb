-- %%
create table dev.demo.del(id int, name string)

-- %%
insert into dev.demo.del values (1, 'Naval')

-- %%
--insert into dev.demo.del values (2, 'Rahul'),(3,'Aditya'),(4,'Manpreet'),(5,'Deepak');

-- %%
insert into dev.demo.del values (2, 'Rahul');
insert into dev.demo.del values (3, 'Aditya');
insert into dev.demo.del values (4, 'Manpreet');
insert into dev.demo.del values (5, 'Deepak');

-- %%
select * from dev.demo.del

-- %%
desc history dev.demo.del

-- %%
desc detail dev.demo.del

-- %%
desc detail dev.demo.del

-- %%
optimize = combines small files into large

-- %%
optimize dev.demo.del

-- %%
1. Improve Query Performace. Optimize

2. Reducing the storage cost. Vacuum

-- %%
optimize: convert small files into larges files
optimiz (z order/cluster)

vacuum: delete the stale files/ NO time travel.
