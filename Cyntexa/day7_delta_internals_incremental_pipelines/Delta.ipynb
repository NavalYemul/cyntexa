-- %%
Parquet  Minial support ACID

1gb csv

upto 97% 

parquet

-- %%
Delta= parquet + _delta_log = strong ACID

-- %%
Internals of Delta Lake

parquet (data) 
+ 
delta_logs (metadata)
 1. crc
 2. json

-- %%
create table dev.demo.gamma(id int, name string)

-- %%
https://delta.io/

-- %%
%sql
insert into dev.default.gamma values (1,'Naval');

-- %%
desc extended  dev.default.gamma

-- %%
desc detail dev.default.gamma

-- %%
desc history  dev.default.gamma

-- %%
insert into dev.default.gamma values (2,'Rahul'),(3,'Manpreet');

-- %%
delete from dev.default.gamma

-- %%
select * from dev.default.gamma

-- %%
select * from dev.default.gamma version as of 2

-- %%
select * from dev.default.gamma timestamp as of '2026-07-28T05:58:46.000+00:00'

-- %%
restore table dev.default.gamma to version as of 2

-- %%
select * from dev.default.gamma
