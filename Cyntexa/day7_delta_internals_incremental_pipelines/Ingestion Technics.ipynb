# %%
Ingestion: to BRONZE

1. External apps, databases, dw
-- lakeflow connector

2. cloud object storage ( adls, s3, volume)
I) Batch. 
1. ctas
2. df=spark.read.csv("path").write.
3. UI

II) Incremental 
1. COPY INTO

Pipelines

III) Streaming 
1. Spark Structured Streaming
2. Autoloader


IV) . Pipelines (Streaming, increamnetal and batch)
