-- %%
folder: new data per second
1.part 
2.part
3.part

Apache Spark Structured Streaming

-- %%
1. 
id name
1 Naval


2. 
id name age
2 Rahul 22

3. 
id name age city
3 Manpreet 22 Mumbai

4.
id, name, age, city, test
5 jai 23, jaipur, -_log_fialed

-- %%
batch

df=spark.read.csv("path")
df.write.saveAsTable("tbalename")

Stream
user_schema= id int, name string
df=spark.readStream.schema(user_schema).csv("path")
df.writeStream.toTable("tablname")

Autoloader (Spark structured streaming) (Python, pyspark)
it can handle changes in schme and structure

df=spark.readStream.option("cloudFiles")..


spark, structed streaming, python


Lakeflow: Pipeline ( Autoloader, structured streaming) (SQL, Python)

-- %%
# Structured
id, name
1 Naval
2, Rahul
3, Manpreet

-- %%
#Autoloader
id, name,age , city
1, Naval, null
2, Rahul, 22
3,
