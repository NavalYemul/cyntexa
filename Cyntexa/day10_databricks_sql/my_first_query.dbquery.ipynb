-- %%
select * from dev.gold.top_5_customers;


select * from samples.bakehouse.sales_transactions;


select * from sales_transactions --where paymentMethod ='mastercard';

select * from sales_transactions where paymentMethod = :payment_method ;
