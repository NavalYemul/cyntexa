# %% [markdown]
# # Notebook Basics

# %%
print("hello Databricks folks")

# %%
# %sql

select "Hello Team"

# %%
1+2

# %%
# Simple FastAPI application

# %pip install fastapi uvicorn

from fastapi import FastAPI

app = FastAPI()

@app.get("/")
def read_root():
    return {"message": "Hello from FastAPI"}

# To run: uvicorn main:app --reload
